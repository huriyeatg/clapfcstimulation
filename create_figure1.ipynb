# %%
# CELL BASED ANALYSIS - example cell responses

# import list
# %reload_ext autoreload
# %autoreload 2

import os
import numpy as np
import pandas as pd
import main_funcs as mfun
import utils_funcs as utils
import plot_funcs as pfun
import matplotlib.pyplot as plt
import pickle
from scipy import stats
from itertools import compress
import seaborn as sns


savefigpath  = 'C:\\Users\\Huriye\\Documents\\code\\clapfcstimulation\\figs\\'
analysispath = 'C:\\Users\\Huriye\\Documents\\code\\clapfcstimulation\\analysis\\'


# load data

#infoPath = 'C:\\Users\\Huriye\\Documents\\code\\clapfcstimulation\\analysis\\infoForAnalysis-readyForPlotting.pkl'
#dff_traceBoth, dff_traceVis, dff_traceOpto, dff_meanBoth1sec, dff_meanVis1sec, dff_meanOpto1sec,x_coordinate, y_coordinate, z_coordinate   = pd.read_pickle(infoPath)

# %%
# Cell samples for visual stimuli
#Sample Cell 1: Sensory responsive cell : Opto decreased the response
tTypes = [ 'Visual + Opto','Visual', ]#,'Opto']
pfun.set_figure()
fig, axs = plt.subplots(nrows = 2, ncols = 3, figsize=(18.3, 6.69))
plt.subplots_adjust(bottom = 1, top =2, hspace = 0.5, wspace = 0.4)

# Example Cell 1: EX - Increased response
plt.subplot(2,3,1)
s_recDate  = '2022-04-18' # CHECKED
s_animalID = 22103
s_recID  = 3
s_cellID = 46
pathname = analysispath + s_recDate + '_' + str(s_animalID) + '_' + str(s_recID).zfill(3)+'\\'
cellID = s_cellID

mfun.plot_dff_mean_traces (pathname, cellID,tTypes,axs[0,0])
axs[0,0].title.set_text('Cell I - Enhanced response')
axs[0,0].title.set_weight('bold')
axs[0,0].set_ylim (ymin =-1, ymax = 2.5)


# Example Cell 2: IN - Decreased response
plt.subplot(2,3,2)
s_recDate  = '2022-04-12'
s_animalID = 22103
s_recID  = 6
s_cellID = 184
pathname = analysispath + s_recDate + '_' + str(s_animalID) + '_' + str(s_recID).zfill(3)+'\\'
cellID = s_cellID

mfun.plot_dff_mean_traces (pathname, cellID,tTypes,axs[0,1])
axs[0,1].title.set_text('Cell II - Enhanced response')
axs[0,1].title.set_weight('bold')
axs[0,1].set_ylim (ymin =-4, ymax = 6)

# Example Cell 4:  - Decreased response
plt.subplot(2,3,3)
s_recDate  = '2022-04-07'
s_animalID = 22101
s_recID  = 4
s_cellID = 82
pathname = analysispath + s_recDate + '_' + str(s_animalID) + '_' + str(s_recID).zfill(3)+'\\'
cellID = s_cellID

mfun.plot_dff_mean_traces (pathname, cellID,tTypes,axs[0,2])
axs[0,2].title.set_text('Cell IV - Enhance response')
axs[0,2].title.set_weight('bold')
axs[0,2].set_ylim (ymin =-1, ymax = 2.5)


# Example Cell 4: EX - Decreased response
plt.subplot(2,3,4)
s_recDate  = '2021-05-07'
s_animalID = 21105
s_recID  = 2
s_cellID = 88
pathname = analysispath + s_recDate + '_' + str(s_animalID) + '_' + str(s_recID).zfill(3)+'\\'
cellID = s_cellID

mfun.plot_dff_mean_traces (pathname, cellID,tTypes,axs[1,0])
axs[1,0].title.set_text('cell IV - Reduced response')
axs[1,0].title.set_weight('bold')
axs[1,0].set_ylim (ymin =-1, ymax = 2.5)

# Example Cell 5:  - Decreased response
plt.subplot(2,3,5)
s_recDate  = '2022-04-12'
s_animalID = 22107
s_recID  = 2
s_cellID = 296
pathname = analysispath + s_recDate + '_' + str(s_animalID) + '_' + str(s_recID).zfill(3)+'\\'
cellID = s_cellID

mfun.plot_dff_mean_traces (pathname, cellID,tTypes,axs[1,1])
axs[1,1].title.set_text('Cell V - Decreased response')
axs[1,1].title.set_weight('bold')
axs[1,1].set_ylim (ymin =-35, ymax = 15)



# Example Cell 6:  - Decreased response
plt.subplot(2,3,6)
s_recDate  = '2021-05-07'
s_animalID = 21105
s_recID  = 3
s_cellID = 208
pathname = analysispath + s_recDate + '_' + str(s_animalID) + '_' + str(s_recID).zfill(3)+'\\'
cellID = s_cellID

mfun.plot_dff_mean_traces (pathname, cellID,tTypes,axs[1,2])
axs[1,2].title.set_text('Cell VI - Decreased response')
axs[1,2].title.set_weight('bold')
axs[1,2].set_ylim (ymin =-3, ymax = 2)

# Save 
pfun.save_figure('Figure1_DFF-mean-traces-VisualCells',savefigpath )
#plt.close(fig)

# %%
# Cell samples for opto stimuli
#Sample Cell 1: Sensory responsive cell : Opto decreased the response
tTypes = [ 'Visual + Opto','Visual','Opto']
pfun.set_figure()
fig, axs = plt.subplots(nrows = 2, ncols = 3, figsize=(18.3, 6.69))
plt.subplots_adjust(bottom = 1, top =2, hspace = 0.5, wspace = 0.4)

# Example Cell 1: EX - Increased response
plt.subplot(2,3,1)
s_recDate  = '2022-04-12' # CHECKED
s_animalID = 22103
s_recID  = 8
s_cellID = 85
pathname = analysispath + s_recDate + '_' + str(s_animalID) + '_' + str(s_recID).zfill(3)+'\\'
cellID = s_cellID

mfun.plot_dff_mean_traces (pathname, cellID,tTypes,axs[0,0])
axs[0,0].title.set_text('Opto Only')
axs[0,0].title.set_weight('bold')
axs[0,0].set_ylim (ymin =-1, ymax = 8)


# Example Cell 2: IN - Decreased response
plt.subplot(2,3,2)
s_recDate  = '2022-04-12'
s_animalID = 22103
s_recID  = 2
s_cellID = 155
pathname = analysispath + s_recDate + '_' + str(s_animalID) + '_' + str(s_recID).zfill(3)+'\\'
cellID = s_cellID

mfun.plot_dff_mean_traces (pathname, cellID,tTypes,axs[0,1])
axs[0,1].title.set_text('Responsive to All')
axs[0,1].title.set_weight('bold')
axs[0,1].set_ylim (ymin =-2, ymax = 8)

# Example Cell 3:  - Decreased response
plt.subplot(2,3,3)
s_recDate  = '2022-04-18'
s_animalID = 22103
s_recID  = 3
s_cellID = 46
pathname = analysispath + s_recDate + '_' + str(s_animalID) + '_' + str(s_recID).zfill(3)+'\\'
cellID = s_cellID

mfun.plot_dff_mean_traces (pathname, cellID,tTypes,axs[0,2])
axs[0,2].title.set_text('Opto > Both > Visual')
axs[0,2].title.set_weight('bold')
axs[0,2].set_ylim (ymin =-1, ymax = 8)

# Save 
pfun.save_figure('Figure1_DFF-mean-traces-OptoCells',savefigpath )
#plt.close(fig)

# %%
print(mfun.selectInterestedcells ( 'CTAP', 'Naive', responsive = True, plotValues = True, pupil = False ))
# Out:
# Env: clapfcstimulation
# Env: clapfcstimulation
# All cell number:43899
# Any responsive cell number:12546
# Visual AND opto responsive cell number:1497
# Visual AND opto AND BOTH responsive cell number:953
# Visual cue - all visual responsive cells: 4962
# Visual cue - only visual responsive: 2536
# Visual cue - EXC opto responsive: 0.4948738170347003
# Visual cue - INH opto responsive: 0.5051261829652997
# Opto stimulation - all opto responsive cells: 5501
# Opto stimulation - only opto responsive: 2939
# Opto stimulation - EXC opto responsive: 0.3269819666553249
# Opto stimulation - INH opto responsive: 0.673018033344675
# Both - all both responsive cells:6527
# Both - only both responsive: 3580
# Both - EXC opto responsive: 0.3916201117318436
# Both - INH opto responsive: 0.6083798882681565
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[24], line 1
# ...

# %%
# Plot the number of cells bar plot
fig, axs = plt.subplots(nrows = 2, ncols = 3, figsize=(18.3, 6.69))
color =  sns.color_palette("bright")
color  = [(1,0,0), (0,0,0),color[2],(0.5, 0.5, 0.5)]
ncell = [4717, 4327,6207,24698]
x = [1,2,3,4]
axs[0,0].bar(x, ncell, color = color)

axs[0,0].set_ylabel('Number of responsive cells')
axs[0,0].set_xticks(x)
axs[0,0].set_xticklabels(['Visual','Visual + Opto','Opto','Any'])
# Out:
# [Text(1, 0, 'Visual'),
#  Text(2, 0, 'Visual + Opto'),
#  Text(3, 0, 'Opto'),
#  Text(4, 0, 'Any')]
